# %%
import torch
from torch.optim.lr_scheduler import SequentialLR, ConstantLR, ExponentialLR, LinearLR, CosineAnnealingLR, ConstantLR
import matplotlib.pyplot as plt

LR = 1

class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(1280*7*7, 768),
            torch.nn.GELU(),
            torch.nn.Linear(768, 768))
        
model = Model()
model.train()
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)
scheduler1 = LinearLR(optimizer, start_factor=0.1, total_iters=5)
scheduler2 = CosineAnnealingLR(optimizer, T_max=100, eta_min= LR/10)
scheduler3 = ConstantLR(optimizer, factor=LR/10, total_iters= 500)
scheduler = SequentialLR(optimizer, schedulers=[scheduler1, scheduler2, scheduler3], milestones=[5, 105])

learning_rates = []
for epoch in range(150):
    optimizer.step()
    learning_rates.append(optimizer.param_groups[0]['lr'])
    scheduler.step()

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(learning_rates, label='Learning Rate')
plt.tick_params(axis='both', which='major', labelsize=18)
plt.xlabel('Epochs', fontsize = 26)
plt.ylabel('Learning Rate', fontsize = 26)
plt.title('Learning Rate Schedule', fontsize = 26)
plt.legend()
plt.grid(True)
plt.show()

# %%
import torch
from torch.optim.lr_scheduler import SequentialLR, ConstantLR, ExponentialLR, LinearLR, CosineAnnealingLR, ConstantLR
import matplotlib.pyplot as plt

LR = 1

class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(1280*7*7, 768),
            torch.nn.GELU(),
            torch.nn.Linear(768, 768))
        
model = Model()
model.train()
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)
scheduler1 = LinearLR(optimizer, start_factor=0.1, total_iters=5)
scheduler2 = CosineAnnealingLR(optimizer, T_max=100, eta_min= LR/10)
scheduler3 = ConstantLR(optimizer, factor=LR/10, total_iters= 20)

scheduler4 = LinearLR(optimizer, start_factor=0.01, end_factor=0.1, total_iters=5)
scheduler5 = CosineAnnealingLR(optimizer, T_max=100, eta_min= LR/100)
scheduler6 = ConstantLR(optimizer, factor=LR/100, total_iters= 20)

scheduler = SequentialLR(optimizer, schedulers=[scheduler1, scheduler2, scheduler3, scheduler4, scheduler5, scheduler6], milestones=[5, 105, 120, 125, 225])

learning_rates = []
for epoch in range(150):
    optimizer.step()
    learning_rates.append(optimizer.param_groups[0]['lr'])
    scheduler.step()

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(learning_rates, label='Learning Rate')
plt.tick_params(axis='both', which='major', labelsize=18)
plt.xlabel('Epochs', fontsize = 26)
plt.ylabel('Learning Rate', fontsize = 26)
plt.title('Learning Rate Schedule', fontsize = 26)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /home/renas/miniconda3/envs/myenv/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
import torch

states = torch.tensor(['s1', 's2', 's3', 's4'])
actions = torch.tensor(['a1', 'a2', 'a3', 'a4'])

#tokens = []

#tokens[:, 0::2, :] = states
#tokens[:, 1::2, :] = actions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 import torch
# ----> 3 states = torch.tensor(['s1', 's2', 's3', 's4'])
#       4 actions = torch.tensor(['a1', 'a2', 'a3', 'a4'])
#
# ValueError: too many dimensions 'str'
